# %% [markdown]
# # Compare Taxa list with Ecological Categories

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import glob

#For illustrator import:
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %% [markdown]
# ### Import Taxa list

# %%
df = pd.read_csv('../data/Deduplicated_Taxa_list.csv')
df.set_index(['Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'], inplace=True)
taxa_list = df.copy()
taxa_list
# Out:
#                                                                                                     Total_reads  \
# Kingdom   Phylum   Class       Order              Family         Genus        Species
# Eukaryota Chordata Actinopteri Alepocephaliformes Platytroctidae Holtbyrnia   s_                           7361
#                                                                  Sagamichthys Sagamichthys abei           15304
#                                Anabantiformes     Channidae      g_           s_                             72
#                                Argentiniformes    Argentinidae   g_           s_                          26340
#                                                   Bathylagidae   Bathylagus   Bathylagus pacificus          170
# ...                                                                                                         ...
#                    Mammalia    Cetacea            Ziphiidae      Ziphius      Ziphius cavirostris         25621
#                                                                  g_           s_                             88
#                                                   unassigned     g_           s_                             71
#                                unassigned         unassigned     g_           s_                              6
#                    Myxini      Myxiniformes       Myxinidae      Eptatretus   unassigned                      8
#
#                                                                                                     Total_samples
# Kingdom   Phylum   Class       Order              Family         Genus        Species
# Eukaryota Chordata Actinopteri Alepocephaliformes Platytroctidae Holtbyrnia   s_                                9
#                                                                  Sagamichthys Sagamichthys abei                11
#                                Anabantiformes     Channidae      g_           s_                                1
#                                Argentiniformes    Argentinidae   g_           s_                               21
#                                                   Bathylagidae   Bathylagus   Bathylagus pacificus             10
# ...                                                                                                           ...
#                    Mammalia    Cetacea            Ziphiidae      Ziphius      Ziphius cavirostris              14
#                                                                  g_           s_                                3
#                                                   unassigned     g_           s_                                4
#                                unassigned         unassigned     g_           s_                                1
#                    Myxini      Myxiniformes       Myxinidae      Eptatretus   unassigned                        2
#
# [97 rows x 2 columns]

# %% [markdown]
# ### Import taxa categories

# %%
# Import species ecological categories that have been manually determined

file = "../data/metadata/CN19S_Taxa_Categories.csv"
# species designations tibble:
df = pd.read_csv(file)
df.set_index(['Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'], inplace=True)
sp_desig = df.copy()
sp_desig
# Out:
#                                                                                                                               Common_name  \
# Kingdom   Phylum   Class       Order             Family          Genus          Species
# Eukaryota Chordata Actinopteri Perciformes       Zoarcidae       Melanostigma   Melanostigma atlanticum                Atlantic soft pout
#                                unknown           Moronidae       Morone         Morone saxatilis                             Striped bass
#                                Beryciformes      Melamphaidae    Scopelogadus   s_                                             ridgeheads
#                                Gadiformes        Macrouridae     Coryphaenoides unassigned                                       rattails
#                                                                  Malacocephalus unassigned                                       rattails
# ...                                                                                                                                   ...
#                                Pleuronectiformes Paralichthyidae Citharichthys  Citharichthys sordidus                    Pacific sanddab
#                                                                                 Citharichthys stigmaeus                 Speckeled sanddab
#                                                                  Paralichthys   s_                                  large-tooth flounders
#                                unknown           Sciaenidae      Genyonemus     Genyonemus lineatus                         White croaker
#                                Scombriformes     Stromateidae    Peprilus       Peprilus medius          Pacific harvestfish (butterfish)
#
#                                                                                                         Ecological_Category
# Kingdom   Phylum   Class       Order             Family          Genus          Species
# Eukaryota Chordata Actinopteri Perciformes       Zoarcidae       Melanostigma   Melanostigma atlanticum    Atlantic species
#                                unknown           Moronidae       Morone         Morone saxatilis           Atlantic species
#                                Beryciformes      Melamphaidae    Scopelogadus   s_                             bathypelagic
#                                Gadiformes        Macrouridae     Coryphaenoides unassigned                     bathypelagic
#                                                                  Malacocephalus unassigned                     bathypelagic
# ...                                                                                                                     ...
#                                Pleuronectiformes Paralichthyidae Citharichthys  Citharichthys sordidus     nearshore bottom
#                                                                                 Citharichthys stigmaeus    nearshore bottom
#                                                                  Paralichthys   s_                         nearshore bottom
#                                unknown           Sciaenidae      Genyonemus     Genyonemus lineatus        nearshore bottom
#                                Scombriformes     Stromateidae    Peprilus       Peprilus medius           nearshore surface
#
# [98 rows x 2 columns]

# %% [markdown]
# ### Merge

# %%
df = pd.concat([sp_desig, taxa_list], axis=1)
df.to_csv('/Users/kpitz/Documents/test.csv')
df
# Out:
#                                                                                                                               Common_name  \
# Kingdom   Phylum   Class       Order             Family          Genus          Species
# Eukaryota Chordata Actinopteri Perciformes       Zoarcidae       Melanostigma   Melanostigma atlanticum                Atlantic soft pout
#                                unknown           Moronidae       Morone         Morone saxatilis                             Striped bass
#                                Beryciformes      Melamphaidae    Scopelogadus   s_                                             ridgeheads
#                                Gadiformes        Macrouridae     Coryphaenoides unassigned                                       rattails
#                                                                  Malacocephalus unassigned                                       rattails
# ...                                                                                                                                   ...
#                                Pleuronectiformes Paralichthyidae Citharichthys  Citharichthys sordidus                    Pacific sanddab
#                                                                                 Citharichthys stigmaeus                 Speckeled sanddab
#                                                                  Paralichthys   s_                                  large-tooth flounders
#                                unknown           Sciaenidae      Genyonemus     Genyonemus lineatus                         White croaker
#                                Scombriformes     Stromateidae    Peprilus       Peprilus medius          Pacific harvestfish (butterfish)
#
#                                                                                                         Ecological_Category  \
# Kingdom   Phylum   Class       Order             Family          Genus          Species
# Eukaryota Chordata Actinopteri Perciformes       Zoarcidae       Melanostigma   Melanostigma atlanticum    Atlantic species
#                                unknown           Moronidae       Morone         Morone saxatilis           Atlantic species
#                                Beryciformes      Melamphaidae    Scopelogadus   s_                             bathypelagic
#                                Gadiformes        Macrouridae     Coryphaenoides unassigned                     bathypelagic
#                                                                  Malacocephalus unassigned                     bathypelagic
# ...                                                                                                                     ...
#                                Pleuronectiformes Paralichthyidae Citharichthys  Citharichthys sordidus     nearshore bottom
#                                                                                 Citharichthys stigmaeus    nearshore bottom
#                                                                  Paralichthys   s_                         nearshore bottom
#                                unknown           Sciaenidae      Genyonemus     Genyonemus lineatus        nearshore bottom
#                                Scombriformes     Stromateidae    Peprilus       Peprilus medius           nearshore surface
#
#                                                                                                          Total_reads  \
# Kingdom   Phylum   Class       Order             Family          Genus          Species
# Eukaryota Chordata Actinopteri Perciformes       Zoarcidae       Melanostigma   Melanostigma atlanticum         57.0
#                                unknown           Moronidae       Morone         Morone saxatilis               946.0
#                                Beryciformes      Melamphaidae    Scopelogadus   s_                           14903.0
#                                Gadiformes        Macrouridae     Coryphaenoides unassigned                       NaN
#                                                                  Malacocephalus unassigned                      89.0
# ...                                                                                                              ...
#                                Pleuronectiformes Paralichthyidae Citharichthys  Citharichthys sordidus       43499.0
#                                                                                 Citharichthys stigmaeus       2706.0
#                                                                  Paralichthys   s_                               1.0
#                                unknown           Sciaenidae      Genyonemus     Genyonemus lineatus          12257.0
#                                Scombriformes     Stromateidae    Peprilus       Peprilus medius                 15.0
#
#                                                                                                          Total_samples
# Kingdom   Phylum   Class       Order             Family          Genus          Species
# Eukaryota Chordata Actinopteri Perciformes       Zoarcidae       Melanostigma   Melanostigma atlanticum            4.0
#                                unknown           Moronidae       Morone         Morone saxatilis                   4.0
#                                Beryciformes      Melamphaidae    Scopelogadus   s_                                24.0
#                                Gadiformes        Macrouridae     Coryphaenoides unassigned                         NaN
#                                                                  Malacocephalus unassigned                         4.0
# ...                                                                                                                ...
#                                Pleuronectiformes Paralichthyidae Citharichthys  Citharichthys sordidus            78.0
#                                                                                 Citharichthys stigmaeus           19.0
#                                                                  Paralichthys   s_                                 1.0
#                                unknown           Sciaenidae      Genyonemus     Genyonemus lineatus               23.0
#                                Scombriformes     Stromateidae    Peprilus       Peprilus medius                   10.0
#
# [98 rows x 4 columns]
